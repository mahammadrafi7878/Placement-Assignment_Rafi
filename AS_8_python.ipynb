# %% [raw]
# Question 8 -
# Using the data from Question 5, write code the analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
# ● Get all the episode names, whose average rating is more than 8 for every season
# ● Get all the episode names that aired before May 2019
# ● Get the episode name from each season with the highest and lowest rating
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
import pandas as pd
df=pd.read_csv('question5.csv')            #reading data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'name', 'season', 'number', 'type',
#        'airdate', 'airtime', 'runtime', 'rating', 'image', 'summary', '_links',
#        'medium image link', 'Original image link'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Unnamed: 0      id                                                url  \
# 0           0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1           1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2           2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3           3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4           4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# 1           Chestnut       1       2  regular  2016-10-09   21:00       60
# 2          The Stray       1       3  regular  2016-10-16   21:00       60
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00       60
# 4        Contrapasso       1       5  regular  2016-10-30   21:00       60
#
#    rating                                              image  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# id                       int64
# url                     object
# name                    object
# season                   int64
# number                   int64
# type                    object
# airdate                 object
# airtime                 object
# runtime                  int64
# rating                 float64
# image                   object
# summary                 object
# _links                  object
# medium image link       object
# Original image link     object
# dtype: object

# %%
df.shape
# Out:
# (36, 16)

# %% [raw]
# Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.

# %%
g=df.groupby('season')['rating']   #applying group by function on rating to get seasions of rating

# %%
g.first()
# Out:
# season
# 1    8.0
# 2    7.8
# 3    8.0
# 4    7.1
# Name: rating, dtype: float64

# %%
df['season'].value_counts()
# Out:
# 1    10
# 2    10
# 3     8
# 4     8
# Name: season, dtype: int64

# %%
import seaborn as sns 
sns.histplot(g)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [raw]
# Get all the episode names, whose average rating is more than 8 for every season

# %%
df[df['rating']>8][['name','season','rating']]
# Out:
#                          name  season  rating
# 6               Trompe L'Oeil       1     8.6
# 8   The Well-Tempered Clavier       1     8.5
# 9          The Bicameral Mind       1     8.7
# 17                    Kiksuya       2     8.7
# 18            Vanishing Point       2     8.4
# 19              The Passenger       2     8.5

# %% [raw]
# Get all the episode names that aired before May 2019

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'name', 'season', 'number', 'type',
#        'airdate', 'airtime', 'runtime', 'rating', 'image', 'summary', '_links',
#        'medium image link', 'Original image link'],
#       dtype='object')

# %%
df['airdate']=pd.to_datetime(df['airdate'])

# %%
df['month']=pd.to_datetime(df['airdate']).dt.month

# %%
df['year']=pd.to_datetime(df['airdate']).dt.year

# %%
#df[df['year']<2019  & df['month']<5]    #It is giving error

# %%
cond1 = df.airdate < pd.Timestamp(2019,5,1)           #Using pd.timestamp method for giving exact date,month and year
df.loc[cond1, ]
# Out:
#     Unnamed: 0       id                                                url  \
# 0            0   869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1            1   911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2            2   911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3            3   911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4            4   927174  https://www.tvmaze.com/episodes/927174/westwor...
# 5            5   932057  https://www.tvmaze.com/episodes/932057/westwor...
# 6            6   938404  https://www.tvmaze.com/episodes/938404/westwor...
# 7            7   943065  https://www.tvmaze.com/episodes/943065/westwor...
# 8            8   943066  https://www.tvmaze.com/episodes/943066/westwor...
# 9            9   943067  https://www.tvmaze.com/episodes/943067/westwor...
# 10          10  1214222  https://www.tvmaze.com/episodes/1214222/westwo...
# ...

# %% [raw]
# Get the episode name from each season with the highest and lowest rating

# %%
df
# Out:
#     Unnamed: 0       id                                                url  \
# 0            0   869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1            1   911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2            2   911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3            3   911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4            4   927174  https://www.tvmaze.com/episodes/927174/westwor...
# 5            5   932057  https://www.tvmaze.com/episodes/932057/westwor...
# 6            6   938404  https://www.tvmaze.com/episodes/938404/westwor...
# 7            7   943065  https://www.tvmaze.com/episodes/943065/westwor...
# 8            8   943066  https://www.tvmaze.com/episodes/943066/westwor...
# 9            9   943067  https://www.tvmaze.com/episodes/943067/westwor...
# 10          10  1214222  https://www.tvmaze.com/episodes/1214222/westwo...
# ...

# %%
df_s1=df[df['season']==1]   #taking data frame where season=1

# %%
df_s2=df[df['season']==2]     #taking data frame where season=2

# %%
df_s3=df[df['season']==3]        #taking data frame where season=3

# %%
df_s4=df[df['season']==4]            #taking data frame where season=4

# %%
max_d1=max(df_s1['rating'])        #extracting max rating in that season

# %%
max_d2=max(df_s2['rating'])        #extracting max rating in that season

# %%
max_d3=max(df_s3['rating'])          #extracting max rating in that season

# %%
max_d4=max(df_s4['rating'])             #extracting max rating in that season

# %%
min_d1=max(df_s1['rating'])            #extracting min rating in that season

# %%
min_d2=max(df_s2['rating'])          #extracting min rating in that season

# %%
min_d3=max(df_s3['rating'])          #extracting min rating in that season

# %%
min_d4=max(df_s4['rating'])          #extracting min rating in that season

# %%
df_s4[df_s4['rating']==min_d4]['name']      #extracting name of min rating name
# Out:
# 32    Zhuangzi
# Name: name, dtype: object

# %%
df_s3[df_s3['rating']==min_d3]['name']#extracting name of max rating name
# Out:
# 20            Parce Domine
# 23    The Mother of Exiles
# Name: name, dtype: object

# %%
df_s2[df_s2['rating']==min_d2]['name']      #extracting name of min rating name
# Out:
# 17    Kiksuya
# Name: name, dtype: object

# %%
df_s1[df_s1['rating']==min_d1]['name']      #extracting name of min rating name
# Out:
# 9    The Bicameral Mind
# Name: name, dtype: object

# %%
df_s1[df_s1['rating']==max_d1]['name'] #extracting name of max rating name
# Out:
# 9    The Bicameral Mind
# Name: name, dtype: object

# %%
df_s2[df_s2['rating']==max_d2]['name']  #extracting name of min rating name
# Out:
# 17    Kiksuya
# Name: name, dtype: object

# %%
df_s3[df_s3['rating']==max_d3]['name']   #extracting name of max rating name
# Out:
# 20            Parce Domine
# 23    The Mother of Exiles
# Name: name, dtype: object

# %%
df_s4[df_s4['rating']==max_d4]['name']    #extracting name of min rating name
# Out:
# 32    Zhuangzi
# Name: name, dtype: object

# %% [raw]
# Get the summary for the most popular ( ratings ) episode in every season

# %%
df_s1.groupby('rating')['summary'].first()
# Out:
# rating
# 7.6    <p>Bernard continues to investigate Dolores' s...
# 7.7    <p>Bernard suspects that someone is sabotaging...
# 7.9    <p>While Dolores joins William and Logan on th...
# 8.0    <p>A woman named Dolores is a free spirit in t...
# 8.5    <p>Bernard forces Robert to take him back into...
# 8.6    <p>While William and Dolores travel to the unc...
# 8.7    <p>Delores finds out the truth about William's...
# Name: summary, dtype: object

# %%
df_s2.groupby('rating')['summary'].first()
# Out:
# rating
# 7.6    <p>While Maeve and her people explore Shogun W...
# 7.7    <p>Dolores looks for allies sympathetic to her...
# 7.8    <p>In the aftermath of the host rebellion, the...
# 7.9    <p>Charlotte and Bernard review Bernard's memo...
# 8.0    <p>William pays his recuperating father-in-law...
# 8.4    <p>The Man learns that his grip on reality isn...
# 8.5    <p>The Man faces a personal reckoning, while A...
# 8.7    <p>Another of Westworld's Host revolutionaries...
# Name: summary, dtype: object

# %%
df_s3.groupby('rating')['summary'].first()
# Out:
# rating
# 7.5    <p>Do a lot of people tell you that you need t...
# 7.7    <p>Time to face the music. Dolores' true inten...
# 7.8    <p>People put up a lot of walls. Bring a sledg...
# 7.9                                  <p>Just say no.</p>
# 8.0    <p>If you're stuck in a loop, try walking in a...
# Name: summary, dtype: object

# %%
df_s4.groupby('rating')['summary'].first()
# Out:
# rating
# 7.1    <p>Hello again. Don't worry about a thing. It'...
# 7.4               <p>I heard a fly buzz when I died.</p>
# 7.5                  <p>To thine own selves be true.</p>
# 7.6    <p>You can never go back again. But if you do,...
# 7.7    <p>Should auld acquaintance be forgot and days...
# 7.8                                 <p>God is bored.</p>
# Name: summary, dtype: object
