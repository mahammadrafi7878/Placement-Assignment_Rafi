# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
import numpy as np
train_images = np.expand_dims(train_images, axis=-1)

# %%
test_images=np.expand_dims(test_images,axis=-1)

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
test_images.shape
# Out:
# (10000, 28, 28, 1)

# %%
#train_images= np.repeat(train_images, 3, axis=-1)

# %%
#test_images=np.repeat(test_images, 3, axis=-1)

# %%
test_images.shape
# Out:
# (10000, 28, 28, 1)

# %%
train_images = tf.image.resize(train_images, [32,32])

# %%
train_images1=tf.image.resize(train_images, [75,75])

# %%
test_images=tf.image.resize(test_images, [32,32])

# %%
train_images[1].shape
# Out:
# TensorShape([32, 32, 1])

# %%
model1=tf.keras.applications.inception_resnet_v2.InceptionResNetV2(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(75,75,1),
    pooling=None,
    classes=10,
    classifier_activation='softmax'
)

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_15 (InputLayer)          [(None, 75, 75, 1)]  0           []
#
#  conv2d_94 (Conv2D)             (None, 37, 37, 32)   288         ['input_15[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 37, 37, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 37, 37, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 35, 35, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 35, 35, 64)   18432       ['activation_95[0][0]']
#
# ...

# %%
epochs=5
history = model1.fit(
  train_images1,
  train_labels,
  epochs=epochs
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1875/1875 [==============================] - 330s 121ms/step - loss: 0.1440 - accuracy: 0.9610
# Epoch 2/5
# 1875/1875 [==============================] - 224s 119ms/step - loss: 0.0686 - accuracy: 0.9814
# Epoch 3/5
# 1875/1875 [==============================] - 220s 117ms/step - loss: 0.0548 - accuracy: 0.9839
# Epoch 4/5
# 1875/1875 [==============================] - 214s 114ms/step - loss: 0.0565 - accuracy: 0.9850
# Epoch 5/5
# 1875/1875 [==============================] - 220s 117ms/step - loss: 0.0372 - accuracy: 0.9894

# %%
model2=tf.keras.applications.inception_v3.InceptionV3(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(75,75,1),
    pooling=None,
    classes=10,
    classifier_activation='softmax'
)

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_16 (InputLayer)          [(None, 75, 75, 1)]  0           []
#
#  conv2d_297 (Conv2D)            (None, 37, 37, 32)   288         ['input_16[0][0]']
#
#  batch_normalization_297 (Batch  (None, 37, 37, 32)  96          ['conv2d_297[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_297[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_297[0][0]']
#
#  batch_normalization_298 (Batch  (None, 35, 35, 32)  96          ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_298 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_298[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 35, 35, 64)   18432       ['activation_298[0][0]']
#
# ...

# %%
epochs=5
history = model2.fit(
  train_images1,
  train_labels,
  epochs=epochs
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1875/1875 [==============================] - 135s 50ms/step - loss: 0.2410 - accuracy: 0.9359
# Epoch 2/5
# 1875/1875 [==============================] - 96s 51ms/step - loss: 0.1132 - accuracy: 0.9731
# Epoch 3/5
# 1875/1875 [==============================] - 94s 50ms/step - loss: 0.0852 - accuracy: 0.9787
# Epoch 4/5
# 1875/1875 [==============================] - 93s 50ms/step - loss: 0.0846 - accuracy: 0.9792
# Epoch 5/5
# 1875/1875 [==============================] - 93s 50ms/step - loss: 0.0710 - accuracy: 0.9811

# %%
model3=tf.keras.applications.resnet.ResNet101(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(32,32,1),
    pooling=None,
    classes=10,
)

# %%
model3.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "resnet101"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, 32, 32, 1)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 1)    0           ['input_8[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   3200        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 16, 16, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_1_conv[0][0]']
# ...

# %%
epochs=5
history = model3.fit(
  train_images,
  train_labels,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 137s 73ms/step - loss: 0.3112 - accuracy: 0.9219
# Epoch 2/5
# 1875/1875 [==============================] - 138s 74ms/step - loss: 0.1957 - accuracy: 0.9501
# Epoch 3/5
# 1875/1875 [==============================] - 138s 73ms/step - loss: 0.1315 - accuracy: 0.9681
# Epoch 4/5
# 1875/1875 [==============================] - 138s 74ms/step - loss: 0.0952 - accuracy: 0.9757
# Epoch 5/5
# 1875/1875 [==============================] - 139s 74ms/step - loss: 0.0864 - accuracy: 0.9773

# %%
model2=tf.keras.applications.vgg19.VGG19(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(32,32,3),
    pooling=None,
    classes=1000,
    classifier_activation='softmax'
)

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model2.fit(
  train_images,
  train_labels,
  epochs=epochs
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1875/1875 [==============================] - 78s 38ms/step - loss: 2.3639 - accuracy: 0.1019
# Epoch 2/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 2.3047 - accuracy: 0.1066
# Epoch 3/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 2.3031 - accuracy: 0.1069
# Epoch 4/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 2.3024 - accuracy: 0.1111
# Epoch 5/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 2.3019 - accuracy: 0.1116
# Epoch 6/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 2.3019 - accuracy: 0.1116
# Epoch 7/10
# ...
