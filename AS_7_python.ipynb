# %% [raw]
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more   than 10000kg

# %%
import pandas as pd                            #Reading dataset
df=pd.read_csv('question4.csv')

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'id', 'nametype', 'recclass', 'mass', 'fall',
#        'year', 'reclat', 'reclong', 'type', 'coordinates'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# name            object
# id               int64
# nametype        object
# recclass        object
# mass           float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# type            object
# coordinates     object
# dtype: object

# %%
import seaborn as sns 
sns.pairplot(data=df)

# %%
df.head(2)
# Out:
#    Unnamed: 0    name  id nametype recclass   mass  fall  \
# 0           0  Aachen   1    Valid       L5   21.0  Fell
# 1           1  Aarhus   2    Valid       H6  720.0  Fell
#
#                       year    reclat   reclong   type           coordinates
# 0  1880-01-01T00:00:00.000  50.77500   6.08333  Point     [6.08333, 50.775]
# 1  1951-01-01T00:00:00.000  56.18333  10.23333  Point  [10.23333, 56.18333]

# %% [raw]
# Get all the Earth meteorites that fell before the year 2000

# %%
df['year']=pd.to_datetime(df['year'],infer_datetime_format=True,errors='coerce')   #converting into datetime type

# %%
df['year']
# Out:
# 0     1880-01-01
# 1     1951-01-01
# 2     1952-01-01
# 3     1976-01-01
# 4     1902-01-01
#          ...
# 995   1934-01-01
# 996   2011-01-01
# 997   1869-01-01
# 998   1922-01-01
# 999   1905-01-01
# Name: year, Length: 1000, dtype: datetime64[ns]

# %%
df['year1']=df['year'].dt.year          #Extract year

# %%
df['month1']=df['year'].dt.month    #extract month

# %%
df['date']=df['year'].dt.day     #extract day

# %%
df[df['year1']<2000]
# Out:
#      Unnamed: 0       name     id nametype     recclass      mass  fall  \
# 0             0     Aachen      1    Valid           L5      21.0  Fell
# 1             1     Aarhus      2    Valid           H6     720.0  Fell
# 2             2       Abee      6    Valid          EH4  107000.0  Fell
# 3             3   Acapulco     10    Valid  Acapulcoite    1914.0  Fell
# 4             4    Achiras    370    Valid           L6     780.0  Fell
# ..          ...        ...    ...      ...          ...       ...   ...
# 994         994   Timochin  24004    Valid           H5   65500.0  Fell
# 995         995   Tirupati  24009    Valid           H6     230.0  Fell
# 997         997      Tjabe  24011    Valid           H6   20000.0  Fell
# 998         998   Tjerebon  24012    Valid           L5   16500.0  Fell
# 999         999  Tomakovka  24019    Valid          LL6     600.0  Fell
#
#           year    reclat    reclong   type            coordinates   year1  \
# ...

# %% [raw]
# Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
res=df[df['year1']<1970][['coordinates','name']]

# %%
res
# Out:
#                coordinates       name
# 0        [6.08333, 50.775]     Aachen
# 1     [10.23333, 56.18333]     Aarhus
# 2         [-113, 54.21667]       Abee
# 4      [-64.95, -33.16667]    Achiras
# 5             [71.8, 32.1]   Adhi Kot
# ..                     ...        ...
# 994           [35.2, 54.5]   Timochin
# 995   [79.41667, 13.63333]   Tirupati
# 997  [111.53333, -7.08333]      Tjabe
# 998  [106.58333, -6.66667]   Tjerebon
# 999      [34.76667, 47.85]  Tomakovka
#
# [763 rows x 2 columns]

# %% [raw]
# Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
df[df['mass']>10000]['name']
# Out:
# 2            Abee
# 7            Agen
# 11            Aïr
# 16        Akyumak
# 27     Alfianello
#           ...
# 991     Tieschitz
# 992        Tilden
# 994      Timochin
# 997         Tjabe
# 998      Tjerebon
# Name: name, Length: 243, dtype: object
